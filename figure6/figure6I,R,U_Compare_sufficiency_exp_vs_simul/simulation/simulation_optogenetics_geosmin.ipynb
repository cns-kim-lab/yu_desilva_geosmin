# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd().resolve().parents[2]
sys.path.insert(0, str(REPO_ROOT / "code"))

from model_unified_ver import run_exp
from model_unified_ver import default_params as params
import utils as utl
from brian2 import Hz,mV
import numpy as np 
import pandas as pd 
import os 
import pickle
from make_network import sez

# %%
from tqdm import tqdm
ff1 = 25.7; ff2 = 23.5
for g in ['horntail','meteor','web']:
#     g = int(g)
    params['w_syn'] = 0.275*mV
    params['n_run'] = 100
    config = {
        'path_res'  : f'{os.getcwd()}/result_geosmin/labellar/{g}',  
        'path_comp' : REPO_ROOT / "data" /'Completeness_783.csv',         # csv of the complete list of Flywire neurons
        'path_con'  : REPO_ROOT / "data" / 'Connectivity_783.parquet',   # connectivity data
        'n_proc'    : -1,                                               # number of CPU cores (-1: use all)
    }


    if str(g) not in os.listdir(f'{os.getcwd()}/result_geosmin/labellar'):
        os.mkdir(config['path_res'])
    if 'params' not in os.listdir(config["path_res"]):
        os.mkdir(f'{config["path_res"]}/params')
    pickle.dump(params,open(f'{config["path_res"]}/params/params.pkl','wb'))
    
    neu_exc = labial_c2g['L1']+labial_c2g['L2']

    neu_add = [labial_c2g['L3'],list(sez[g])]
    except_ids = None
    except_wsyn = None
    neu_slnc = []

    spike_path = f'/volume_4/research/seongbong/flywire/geosmin_project_version_update/figure4/PER_fitting/Seperate_fitting_subtype_all_at_once/convert_simulation_result/result_L1L2&L3/input_spike_pattern/{ff1}Hz_{ff2}Hz_0Hz.pkl'
    predetermined_input_or_not = [1,1,0]

    for f in [0,60]:
        params['r_poi1'] = ff1 * Hz
        params['r_poi2'] = ff2 * Hz
        params['r_poi3'] = f * Hz
        run_exp(exp_name=f'{ff1}Hz_{ff2}Hz_{f}Hz'.format(f), neu_exc=neu_exc,neu_exc_add=neu_add,Except_output_Ids=except_ids,Except_output_w_syn=except_wsyn,neu_slnc=neu_slnc,predetermined_input_or_not=predetermined_input_or_not,spike_path=spike_path,params=params, **config)

# %%
ff1 = 88.4;ff2 = 82.5
from tqdm import tqdm
for g in [4512,8817,7005]:
    g = int(g)
    params['w_syn'] = 0.275*mV
    params['n_run'] = 100
    config = {
        'path_res'  : f'{os.getcwd()}/result_geosmin/tarsal/{g}',                              # directory to store results
        'path_comp' : REPO_ROOT / "data" /'Completeness_783.csv',         # csv of the complete list of Flywire neurons
        'path_con'  : REPO_ROOT / "data" / 'Connectivity_783.parquet',   # connectivity data
        'n_proc'    : -1,                                               # number of CPU cores (-1: use all)
    }


    if str(g) not in os.listdir(f'{os.getcwd()}/result_geosmin/tarsal'):
        os.mkdir(config['path_res'])
    if 'params' not in os.listdir(config["path_res"]):
        os.mkdir(f'{config["path_res"]}/params')
    pickle.dump(params,open(f'{config["path_res"]}/params/params.pkl','wb'))
    

    neu_atGRN = atgrn_c2g['a6']+atgrn_c2g['a7']
    neu_add = [TPN1,list(target_ids_valid_all[g_info_all==g])]
    except_ids = [atgrn_c2g['a6']+atgrn_c2g['a7']+TPN1]
    except_wsyn = [0.825*mV]
    neu_slnc = []

    spike_path = f'/volume_4/research/seongbong/flywire/geosmin_project_version_update/figure4/PER_fitting/Seperate_fitting_subtype_all_at_once/convert_simulation_result/result_atGRN&TPN1/input_spike_pattern/{ff1}Hz_{ff2}Hz_170Hz.pkl'
    predetermined_input_or_not = [1,1,0]

    for f in [0,60]:
        params['r_poi1'] = ff1 * Hz
        params['r_poi2'] = ff2 * Hz
        params['r_poi3'] = f * Hz
        run_exp(exp_name=f'{ff1}Hz_{ff2}Hz_{f}Hz'.format(f), neu_exc=neu_atGRN,neu_exc_add=neu_add,Except_output_Ids=except_ids,Except_output_w_syn=except_wsyn,neu_slnc=neu_slnc,predetermined_input_or_not=predetermined_input_or_not,spike_path=spike_path,params=params, **config)

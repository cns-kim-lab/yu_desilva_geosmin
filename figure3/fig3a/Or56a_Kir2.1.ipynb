# %%
import pandas as pd 
import sys
sys.path.append('../../code')
import plot_of_experiment_data 
import matplotlib.pyplot as plt
import warnings
from pathlib import Path
import matplotlib
matplotlib.rcParams['svg.fonttype'] = 'none'
matplotlib.rcParams['font.family'] = 'Arial'
matplotlib.rcParams['svg.fonttype'] = 'none'
matplotlib.rcParams['font.size'] = 7
warnings.filterwarnings("ignore", message="findfont: Font family 'Arial' not found.")

# %%
pwd
# Out:
# '/volume_4/research/seongbong/flywire/yu_desilva_geosmin_release/figure3/fig3a'

# %%
def std_err(arr):
    err = np.nanstd(arr,axis=0)/np.sqrt(np.sum(~np.isnan(arr),axis=0))
    return err

def pval_to_asterisks(p):
    if p < 0.0001:
        return "****"
    elif p < 0.001:
        return "***"
    elif p < 0.01:
        return "**"
    elif p < 0.05:
        return "*"
    else:
        return "ns"

# %%
data_path1 = Path('/volume_4/research/seongbong/flywire/geosmin_project/LM_data_from_dilan/experiment/sugar+geomsin')
data_path2 = Path('/volume_4/research/seongbong/flywire/geosmin_project/figure/figure3_olfactory_pathway/data')
# fig1a. 
tarsal_s_df = pd.read_excel(data_path1/'tarsal_PER.xlsx',index_col=False,sheet_name='sugar')
tarsal_sg_df = pd.read_excel(data_path1/'tarsal_PER.xlsx',index_col=False,sheet_name='sugar+geosmin')

### figure D: Screening Or56a
fpath = data_path2/'kir2.1_Or56a_dose_dependent_PER.xlsx'
sheets = pd.ExcelFile(fpath)
sheets = sheets.sheet_names
sheets = ['sugar','sugar+geosmin']
data_df_Or56a = {}
for s in sheets:
    df = pd.read_excel(fpath,s)
    data_df_Or56a[s] = df
    
fig_params = {
'cmap' : ['#13739E', '#952B7E', '#E68613', '#4CAF50'],
'fontsize':10,
'lw' : 1,
'elw' : .75,
'ms' : 0,
'cs':1,
'lp' : 1,
'ct' : .5,
'ecolor' : 'black'}

# %%
# fig1a: sucrose on leg 
tarsal_s_df_exp = data_df_Or56a['sugar']
tarsal_sg_df_exp = data_df_Or56a['sugar+geosmin']
fig,ax = plt.subplots(1,1,figsize=(1,.9))
plot_of_experiment_data.plot_dose_dp_PER(ax,tarsal_s_df_exp,**fig_params)
plot_of_experiment_data.plot_dose_dp_PER(ax,tarsal_sg_df_exp,cidx=1,**fig_params)
# stat_all = plot_of_experiment_data.plot_statistics_result(ax,[tarsal_s_df,tarsal_sg_df])
plot_of_experiment_data.plot_dose_dp_PER(ax,tarsal_s_df,**fig_params,alpha=.5,linestyle='dashdot')
plot_of_experiment_data.plot_dose_dp_PER(ax,tarsal_sg_df,cidx=1,**fig_params,alpha=.5,linestyle='dashdot')


ax.set_ylabel('Tarsal PER',fontsize=7)
ax.set_xlabel('Sucrose (mM)',fontsize=7)
ax.set_yticks([0,.2,.4,.6,.8])
ax.set_ylim([0,0.8])
ax.set_xticks(list(range(len(tarsal_s_df.columns))),[x[:-2] for x in tarsal_s_df.columns],fontsize=7)
ax.spines[["bottom", "left"]].set_linewidth(.7)
ax.tick_params(axis="both", width=.7)

plt.savefig('Or56a.svg',bbox_inches='tight')
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
stat_all
# Out:
# [(18.0, 0.078125), (5.0, 0.5625), (5.0, 0.78125), (3.0, 0.90625)]

# %%
plot_of_experiment_data.fig_params
# Out:
# {'cmap': ['#13739E', '#952B7E', '#E68613', '#4CAF50'],
#  'fontsize': 10,
#  'lw': 1,
#  'elw': 0.75,
#  'ms': 0,
#  'cs': 1,
#  'lp': 2,
#  'ct': 0.5,
#  'ecolor': 'black'}

# %%
import pandas as pd 
import sys
sys.path.append('../../code')
import plot_of_experiment_data 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", message="findfont: Font family 'Arial' not found.")

# %%
pwd
# Out:
# '/volume_4/research/seongbong/flywire/geosmin_project_version_update/figure3/fig3a'

# %%
def std_err(arr):
    err = np.nanstd(arr,axis=0)/np.sqrt(np.sum(~np.isnan(arr),axis=0))
    return err

def pval_to_asterisks(p):
    if p < 0.0001:
        return "****"
    elif p < 0.001:
        return "***"
    elif p < 0.01:
        return "**"
    elif p < 0.05:
        return "*"
    else:
        return "ns"

# %%
### figure D: Screening Or56a
fpath = '/volume_4/research/seongbong/flywire/geosmin_project/figure/figure3_olfactory_pathway/data/kir2.1_Or56a_dose_dependent_PER.xlsx'
sheets = pd.ExcelFile(fpath)
sheets = sheets.sheet_names
sheets = ['sugar','sugar+geosmin']
data_df_figD = {}
for s in sheets:
    df = pd.read_excel(fpath,s)
    data_df_figD[s] = df

# %%
# fig1a: sucrose on leg 
tarsal_s_df = data_df_figD['sugar']
tarsal_sg_df = data_df_figD['sugar+geosmin']
fig,ax = plt.subplots(1,1,figsize=(1.8,2))
plot_of_experiment_data.plot_dose_dp_PER(ax,tarsal_s_df)
plot_of_experiment_data.plot_dose_dp_PER(ax,tarsal_sg_df,cidx=1)
stat_all = plot_of_experiment_data.plot_statistics_result(ax,[tarsal_s_df,tarsal_sg_df])

ax.set_ylabel('Tarsal PER',fontsize=10)
ax.set_xlabel('[sucrose] (mM)',fontsize=10)
ax.set_ylim([0,0.8])
ax.set_xticks(list(range(len(tarsal_s_df.columns))),[x[:-2] for x in tarsal_s_df.columns],fontsize=10)
# Out:
# ../../code/plot_of_experiment_data.py:54: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   p1 = ax.errorbar(list(range(len(data.columns))),data.values.mean(axis=0),yerr=std_err(data.values),linewidth=lw,elinewidth=elw,markersize=ms,fmt='-o',capsize=cs,color=cmap,ecolor=ecolor,capthick=ct,alpha=alpha,linestyle=linestyle)
# [<matplotlib.axis.XTick at 0x7fed0618bbb0>,
#  <matplotlib.axis.XTick at 0x7fed0618bb80>,
#  <matplotlib.axis.XTick at 0x7fed061353a0>,
#  <matplotlib.axis.XTick at 0x7fed0614ed30>]
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
stat_all
# Out:
# [(18.0, 0.078125), (5.0, 0.5625), (5.0, 0.78125), (3.0, 0.90625)]

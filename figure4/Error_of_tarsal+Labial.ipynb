# %%
import sys 
import os 
sys.path.append('/volume_4/research/seongbong/flywire/geosmin_project_version_update/code')
from analysis_of_simulation_result import * 
import matplotlib.pyplot as plt

# %%
error_tarsal = {}
for x in range(160,220,10):
    res = pickle.load(open(f'data_wo_constraint/tarsal/result_av1a1_{x}.pkl','rb'))
    error_tarsal[x] = res.fun

error_labial = {}
for x in range(160,220,10):
    res = pickle.load(open(f'data_wo_constraint/labial/result_av1a1_{x}.pkl','rb'))
    error_labial[x] = res.fun

# %%
import matplotlib
matplotlib.rcParams['svg.fonttype'] = 'none'
matplotlib.rcParams['font.family'] = 'Arial'
matplotlib.rcParams['font.size'] = 7

val = np.array(list(error_labial.values()))+np.array(list(error_tarsal.values()))


fig,ax = plt.subplots(1,1,figsize=(1.8,2))
ax.plot(val)
ax.set_ylabel('Error')
ax.set_xticks(list(range(len(val))))
ax.set_xticklabels(list(range(160,220,10)))
ax.set_xlabel('LHav1a1 (Hz)')
ax.spines[['top','right']].set_visible(False)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

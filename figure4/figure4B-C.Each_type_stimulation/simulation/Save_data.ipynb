# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd().resolve().parents[2]
sys.path.insert(0, str(REPO_ROOT / "code"))

from analysis_of_simulation_result import * 
from cell_groups import *
atGRN_cluster = pd.read_parquet(
    REPO_ROOT / "data" / "atGRN_cluster_info_v783.parquet"
)
labial_cluster = pd.read_parquet(
    REPO_ROOT / "data" / "labial_cluster_info_v783.parquet"
)


SIMULATION_DIR = Path.cwd()
OUTPUT_DIR = SIMULATION_DIR.parent / "plotting" / "data"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ============================================================
# Tarsal candidate stimulation
# ============================================================

OUTPUT_DIR = Path(OUTPUT_DIR)
N_SIMULATIONS = 100


tarsal_mean, tarsal_sem = load_mn9_results(
    result_dir=Path.cwd() / "tarsal_result",
    target_neuron=MN9,
    target_name='MN9'
)

tarsal_mean = tarsal_mean.reindex(
    sorted(tarsal_mean.columns, key=frequency_sort_key),
    axis=1,
)


tarsal_sem = tarsal_sem.reindex(
    sorted(tarsal_sem.columns, key=frequency_sort_key),
    axis=1,
)


tarsal_mean.to_excel(OUTPUT_DIR / "Tarsal_candidate_stimulation.xlsx",)
tarsal_sem.to_excel(OUTPUT_DIR / "Tarsal_candidate_stimulation_SEM.xlsx")


# ============================================================
# labial candidate stimulation
# ============================================================



OUTPUT_DIR = Path(OUTPUT_DIR)
N_SIMULATIONS = 100

labial_mean, labial_sem = load_mn9_results(
    result_dir=Path.cwd() / "labial_result",
    target_neuron=MN9,
    target_name='MN9'
)

labial_mean = labial_mean.reindex(
    sorted(labial_mean.columns, key=frequency_sort_key),
    axis=1,
)


labial_sem = labial_sem.reindex(
    sorted(labial_sem.columns, key=frequency_sort_key),
    axis=1,
)



labial_mean.to_excel(OUTPUT_DIR/'Labellar_candidate_stimulation.xlsx')
labial_sem.to_excel(OUTPUT_DIR/'Labellar_candidate_stimulation_SEM.xlsx')
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 36157.79it/s]

# %%
# Out:
# exp_name  0Hz      20Hz      40Hz      60Hz      80Hz     100Hz     120Hz  \
# group
# TPN1      0.0  0.000000  0.016852  0.198305  0.269835  0.310082  0.336738
# a3        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# a6        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.039934
# a7        0.0  0.044317  0.236772  0.257344  0.316724  0.318561  0.343766
# a9        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# exp_name     140Hz     160Hz     180Hz     200Hz
# group
# TPN1      0.387459  0.347435  0.413109  0.419215
# a3        0.000000  0.000000  0.000000  0.000000
# a6        0.094573  0.075132  0.127867  0.151245
# a7        0.389254  0.326228  0.388786  0.439025
# a9        0.000000  0.000000  0.000000  0.000000

# %%
import sys

from brian2 import Hz
import numpy as np 
import pandas as pd 
import os 
import pickle
from pathlib import Path
REPO_ROOT = Path.cwd().resolve().parents[3]
sys.path.insert(0, str(REPO_ROOT / "code"))
from brian2 import Hz,mV
from model_unified_ver import run_exp
from model_unified_ver import default_params as params
from make_network import * 
import utils as utl



av1a1 = [720575940623041549,720575940622894616,720575940626958878,720575940633984924,720575940611137742,720575940627192337]
TPN1 = [720575940623118029, 720575940624967561]

atGRN_cluster = pd.read_parquet(REPO_ROOT/'data/atGRN_cluster_info_v783.parquet')
atgrn_c2g = {}
for t in np.unique(atGRN_cluster.type):
    atgrn_c2g[t] = list(atGRN_cluster.flyid.values[atGRN_cluster.type==t])

from fitting import *

# %%
params_opt_tarsal = pickle.load(open(REPO_ROOT/'figure4/figure4F-K.MN9_PER_fitting/fitting_result/tarsal/result_av1a1_170.pkl','rb'))

V_at,K_at,n_at,V_tp,K_tp,n_tp,k_act_T,r0_T,h_T = params_opt_tarsal.x

ff1 = np.round(hill(100,V_at,K_at,n_at),1)
ff2 = np.round(hill(100,V_tp,K_tp,n_tp),1)

# %%
from tqdm import tqdm
import shutil

params['w_syn'] = 0.275*mV
params['n_run'] = 100

config = {
    'path_res'  : f'{os.getcwd()}/result_mid_hindleg',                              # directory to store results
    'path_comp' : REPO_ROOT / "data" /'Completeness_783.csv',         # csv of the complete list of Flywire neurons
    'path_con'  : REPO_ROOT / "data" / 'Connectivity_783.parquet',   # connectivity data
    'n_proc'    : -1,                                               # number of CPU cores (-1: use all)
}


if 'params' not in os.listdir(f'{os.getcwd()}/result_mid_hindleg'):
    os.mkdir(f'{os.getcwd()}/result_mid_hindleg/params')
pickle.dump(params,open(f'{config["path_res"]}/params/params.pkl','wb'))

neu_exc = atgrn_c2g['a6']
neu_add = [TPN1,av1a1]

except_ids = [atgrn_c2g['a6']+TPN1]
except_wsyn = [0.825*mV]
neu_slnc = []

for f2 in [0]:
    params['r_poi1'] = ff1 * Hz
    params['r_poi2'] = ff2 * Hz
    params['r_poi3'] = f2 * Hz
    run_exp(exp_name=f'{ff1}Hz_{ff2}Hz_{f2}Hz'.format(f), neu_exc=neu_exc,neu_exc_add=neu_add,Except_output_Ids=except_ids,Except_output_w_syn=except_wsyn,neu_slnc=neu_slnc,params=params, **config)

# %%
from tqdm import tqdm
import shutil

params['w_syn'] = 0.275*mV
params['n_run'] = 100

config = {
    'path_res'  : f'{os.getcwd()}/result_foreleg',                              # directory to store results
    'path_comp' : REPO_ROOT / "data" /'Completeness_783.csv',         # csv of the complete list of Flywire neurons
    'path_con'  : REPO_ROOT / "data" / 'Connectivity_783.parquet',   # connectivity data
    'n_proc'    : -1,                                               # number of CPU cores (-1: use all)
}

if 'params' not in os.listdir(f'{os.getcwd()}/result_foreleg'):
    os.mkdir(f'{os.getcwd()}/result_foreleg/params')
pickle.dump(params,open(f'{config["path_res"]}/params/params.pkl','wb'))

neu_exc = atgrn_c2g['a7']
neu_add = [TPN1,av1a1]

except_ids = [atgrn_c2g['a7']+TPN1]
except_wsyn = [0.825*mV]
neu_slnc = []

for f2 in [0]:
    params['r_poi1'] = ff1 * Hz
    params['r_poi2'] = ff2 * Hz
    params['r_poi3'] = f2 * Hz
    run_exp(exp_name=f'{ff1}Hz_{ff2}Hz_{f2}Hz'.format(f), neu_exc=neu_exc,neu_exc_add=neu_add,Except_output_Ids=except_ids,Except_output_w_syn=except_wsyn,neu_slnc=neu_slnc,params=params, **config)

# %%
from tqdm import tqdm
import shutil

params['w_syn'] = 0.275*mV
params['n_run'] = 100

config = {
    'path_res'  : f'{os.getcwd()}/result_only_TPN1',                              # directory to store results
    'path_comp' : REPO_ROOT / "data" /'Completeness_783.csv',         # csv of the complete list of Flywire neurons
    'path_con'  : REPO_ROOT / "data" / 'Connectivity_783.parquet',   # connectivity data
    'n_proc'    : -1,                                               # number of CPU cores (-1: use all)
}


if 'params' not in os.listdir(f'{os.getcwd()}/result_only_TPN1'):
    os.mkdir(f'{os.getcwd()}/result_only_TPN1/params')
pickle.dump(params,open(f'{config["path_res"]}/params/params.pkl','wb'))


neu_exc = atgrn_c2g['a7']
neu_add = [TPN1,av1a1]

except_ids = [atgrn_c2g['a7']+TPN1]
except_wsyn = [0.825*mV]
neu_slnc = []

for f2 in [0]:
    params['r_poi1'] = 0 * Hz
    params['r_poi2'] = ff2 * Hz
    params['r_poi3'] = f2 * Hz
    run_exp(exp_name=f'{0}Hz_{ff2}Hz_{f2}Hz'.format(f), neu_exc=neu_exc,neu_exc_add=neu_add,Except_output_Ids=except_ids,Except_output_w_syn=except_wsyn,neu_slnc=neu_slnc,params=params, **config)
